# %%
# !unzip /content/drive/MyDrive/eyes_detection/dataset.zip -d /content/drive/MyDrive/eyes_detection
# Out:
# Archive:  /content/drive/MyDrive/eyes_detection/dataset.zip
#    creating: /content/drive/MyDrive/eyes_detection/dataset/
#    creating: /content/drive/MyDrive/eyes_detection/dataset/images/
#   inflating: /content/drive/MyDrive/eyes_detection/dataset/images/Images_100.jpg
#   inflating: /content/drive/MyDrive/eyes_detection/dataset/images/Images_102.jpg
#   inflating: /content/drive/MyDrive/eyes_detection/dataset/images/Images_104.jpg
#   inflating: /content/drive/MyDrive/eyes_detection/dataset/images/Images_106.jpg
#   inflating: /content/drive/MyDrive/eyes_detection/dataset/images/Images_108.jpg
#   inflating: /content/drive/MyDrive/eyes_detection/dataset/images/Images_111.jpg
#   inflating: /content/drive/MyDrive/eyes_detection/dataset/images/Images_113.jpg
#   inflating: /content/drive/MyDrive/eyes_detection/dataset/images/Images_115.jpg
#   inflating: /content/drive/MyDrive/eyes_detection/dataset/images/Images_117.jpg
# ...

# %%
# !pip install tensorflow-object-detection-api
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.4/577.4 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.6 MB/s eta 0:00:00
# ...
#   Created wheel for tensorflow-object-detection-api: filename=tensorflow_object_detection_api-0.1.1-py3-none-any.whl size=844486 sha256=d75c565fe2507602a893ac214ec05fe4e64a3260ec93bbd95ff3bafb11b704f4
#   Stored in directory: /root/.cache/pip/wheels/8a/55/68/c084bc2cd93c41fd8f7e2ef9e6bbcb2c35a3e4b49e42044d02
# Successfully built tensorflow-object-detection-api
# ...

# %%
import os
import csv
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split

# Path to the directory containing XML annotations
xml_dir = "/content/drive/MyDrive/eyes_detection/dataset/labels"

# Output CSV files for train and test splits
train_csv_path = "/content/drive/MyDrive/eyes_detection/dataset/train_annotations.csv"
test_csv_path = "/content/drive/MyDrive/eyes_detection/dataset/test_annotations.csv"

# Lists to store annotation data
train_data = []
test_data = []

# Loop through XML files
for xml_filename in os.listdir(xml_dir):
    if xml_filename.endswith(".xml"):
        xml_path = os.path.join(xml_dir, xml_filename)

        tree = ET.parse(xml_path)
        root = tree.getroot()

        filename = root.find("filename").text
        width = int(root.find("size/width").text)
        height = int(root.find("size/height").text)
        class_name = "eye"  # You can modify this based on your data

        for obj in root.findall("object"):
            bbox = obj.find("bndbox")
            xmin = int(bbox.find("xmin").text)
            ymin = int(bbox.find("ymin").text)
            xmax = int(bbox.find("xmax").text)
            ymax = int(bbox.find("ymax").text)

            annotation_data = [filename, width, height, class_name, xmin, ymin, xmax, ymax, "/content/drive/MyDrive/eyes_detection/dataset/images"]


# Split the annotation data into train and test sets
train_data, test_data = train_test_split(annotation_data, test_size=0.2, random_state=42)

# Write train annotations to CSV
with open(train_csv_path, "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax", "source"])
    csvwriter.writerows(train_data)

# Write test annotations to CSV
with open(test_csv_path, "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax", "source"])
    csvwriter.writerows(test_data)

print("CSV conversion completed.")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-13-300a652df33b> in <cell line: 44>()
#      45     csvwriter = csv.writer(csvfile)
#      46     csvwriter.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax", "source"])
# ---> 47     csvwriter.writerows(train_data)
#      48
#      49 # Write test annotations to CSV
#
# Error: iterable expected, not int

# %%
import os
import csv
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split

# Path to the directory containing XML annotations
xml_dir =  "/content/drive/MyDrive/eyes_detection/dataset/labels"

# Output CSV files for train and test splits
train_csv_path = "/content/drive/MyDrive/eyes_detection/dataset/train_annotations.csv"
test_csv_path = "/content/drive/MyDrive/eyes_detection/dataset/test_annotations.csv"

# Lists to store annotation data
annotation_data = []

# Loop through XML files
for xml_filename in os.listdir(xml_dir):
    if xml_filename.endswith(".xml"):
        xml_path = os.path.join(xml_dir, xml_filename)

        tree = ET.parse(xml_path)
        root = tree.getroot()

        filename = root.find("filename").text
        width = int(root.find("size/width").text)
        height = int(root.find("size/height").text)
        class_name = "eye"  # You can modify this based on your data

        for obj in root.findall("object"):
            bbox = obj.find("bndbox")
            xmin = int(bbox.find("xmin").text)
            ymin = int(bbox.find("ymin").text)
            xmax = int(bbox.find("xmax").text)
            ymax = int(bbox.find("ymax").text)

            annotation_data.append([filename, width, height, class_name, xmin, ymin, xmax, ymax, "/content/drive/MyDrive/eyes_detection/dataset/images/"])

# Split the annotation data into train and test sets
train_data, test_data = train_test_split(annotation_data, test_size=0.2, random_state=42)

# Write train annotations to CSV
with open(train_csv_path, "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax", "source"])
    csvwriter.writerows(train_data)

# Write test annotations to CSV
with open(test_csv_path, "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax", "source"])
    csvwriter.writerows(test_data)

print("CSV conversion completed.")
# Out:
# CSV conversion completed.

# %%
import os
import csv
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split

# Path to the directory containing XML annotations
xml_dir =  "/content/drive/MyDrive/eyes_detection/dataset/labels"
image_dir = "/content/drive/MyDrive/eyes_detection/dataset/images"  # Path to the directory containing images

# Output CSV files for train and test splits
train_csv_path = "/content/drive/MyDrive/eyes_detection/dataset/train_annotations.csv"
test_csv_path = "/content/drive/MyDrive/eyes_detection/dataset/test_annotations.csv"

# Lists to store annotation data
annotation_data = []

# Loop through XML files
for xml_filename in os.listdir(xml_dir):
    if xml_filename.endswith(".xml"):
        xml_path = os.path.join(xml_dir, xml_filename)

        tree = ET.parse(xml_path)
        root = tree.getroot()

        filename = root.find("filename").text
        width = int(root.find("size/width").text)
        height = int(root.find("size/height").text)
        class_name = "eye"  # You can modify this based on your data

        image_path = os.path.join(image_dir, filename)  # Construct the image path

        for obj in root.findall("object"):
            bbox = obj.find("bndbox")
            xmin = int(bbox.find("xmin").text)
            ymin = int(bbox.find("ymin").text)
            xmax = int(bbox.find("xmax").text)
            ymax = int(bbox.find("ymax").text)

            annotation_data.append([image_path, width, height, class_name, xmin, ymin, xmax, ymax, '/content/drive/MyDrive/eyes_detection/dataset/images'])  # Use image_path as source

# Split the annotation data into train and test sets
train_data, test_data = train_test_split(annotation_data, test_size=0.2, random_state=42)

# Write train annotations to CSV
with open(train_csv_path, "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax", "source"])
    csvwriter.writerows(train_data)

# Write test annotations to CSV
with open(test_csv_path, "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax", "source"])
    csvwriter.writerows(test_data)

print("CSV conversion completed.")
# Out:
# CSV conversion completed.

# %%
import os
import csv
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split

# Path to the directory containing XML annotations
xml_dir =  "/content/drive/MyDrive/eyes_detection/dataset/labels"
image_dir = "/content/drive/MyDrive/eyes_detection/dataset/images"  # Path to the directory containing images

# Output CSV files for train and test splits
train_csv_path = "/content/drive/MyDrive/eyes_detection/dataset/train_annotations.csv"
test_csv_path = "/content/drive/MyDrive/eyes_detection/dataset/test_annotations.csv"


# Lists to store annotation data
annotation_data = []

# Loop through XML files
for xml_filename in os.listdir(xml_dir):
    if xml_filename.endswith(".xml"):
        xml_path = os.path.join(xml_dir, xml_filename)

        tree = ET.parse(xml_path)
        root = tree.getroot()

        filename = root.find("filename").text
        width = int(root.find("size/width").text)
        height = int(root.find("size/height").text)
        class_name = "eye"  # You can modify this based on your data

        image_path = os.path.join(image_dir, filename)  # Construct the image path

        for obj in root.findall("object"):
            bbox = obj.find("bndbox")
            xmin = int(bbox.find("xmin").text)
            ymin = int(bbox.find("ymin").text)
            xmax = int(bbox.find("xmax").text)
            ymax = int(bbox.find("ymax").text)

            annotation_data.append([filename, width, height, class_name, xmin, ymin, xmax, ymax, image_path])  # Store filename, not image_path, in the source column

# Split the annotation data into train and test sets
train_data, test_data = train_test_split(annotation_data, test_size=0.2, random_state=42)

# Write train annotations to CSV
with open(train_csv_path, "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax", "source"])
    csvwriter.writerows(train_data)

# Write test annotations to CSV
with open(test_csv_path, "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax", "source"])
    csvwriter.writerows(test_data)

print("CSV conversion completed.")
# Out:
# CSV conversion completed.
